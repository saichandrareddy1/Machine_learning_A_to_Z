# %% [markdown]
# ### importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the csv datafile using pandas

# %%
data = pd.read_csv('simple_linear_regression.csv')

# %% [markdown]
# ### analysing the data

# %%
print(data.head(),'\n\n')
print(data.shape,'\n\n')
print(data.isnull().sum(),'\n\n')
print(data.describe(),'\n\n')
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83
#
#
# (84, 2)
#
#
# SAT    0
# GPA    0
# dtype: int64
#
#
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
X = data.iloc[:,0].values
y = data.iloc[:,1].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (84,)
# (84,)

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)
print(X.shape)
print(y.shape)
# Out:
# (84, 1)
# (84, 1)

# %% [markdown]
# ### Visualising the data

# %%
plt.figure(figsize = (10,5))
plt.scatter(X,y,c='r')
plt.show()

# %% [markdown]
# ### Spliting the data to train and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Fitting the regression model to data

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_predict = regressor.predict(X_test)

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_predict,y_test)

# %%
print(mse)
# Out:
# 0.04691776855623539

# %% [markdown]
# ### Visualising the results on training set

# %%
plt.figure(figsize = (10,5))
plt.scatter(X_train,y_train,c='blue')
plt.plot(X_train,regressor.predict(X_train),c='r',linewidth=2)
plt.show()

# %% [markdown]
# ### visualing the results on testing set

# %%
plt.figure(figsize = (10,5))
plt.scatter(X_test,y_test,c='blue')
plt.plot(X_test,regressor.predict(X_test),c='g',linewidth=2,linestyle='dashed')
plt.show()

# %%
ans = regressor.predict([[1714]])
print(ans)
# Out:
# [[3.09736474]]
